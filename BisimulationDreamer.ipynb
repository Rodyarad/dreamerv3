# %% [markdown]
# # **Обучение**

# %%
# !python dreamerv3/main.py \
  --logdir ~/logdir/{timestamp} \
  --configs dmc_vision \
  --run.train_ratio 32
# Out:
# ---  ___                           __   ______ ---
# --- |   \ _ _ ___ __ _ _ __  ___ _ \ \ / /__ / ---
# --- | |) | '_/ -_) _` | '  \/ -_) '/\ V / |_ \ ---
# --- |___/|_| \___\__,_|_|_|_\___|_|  \_/ |___/ ---
# Run script: train
# Logdir: /home/rodya-rad/logdir/20241009T110032
# Observation space
#   reward           Space(dtype=float32, shape=(), low=-inf, high=inf)
#   is_first         Space(dtype=bool, shape=(), low=False, high=True)
#   is_last          Space(dtype=bool, shape=(), low=False, high=True)
#   is_terminal      Space(dtype=bool, shape=(), low=False, high=True)
#   orientations     Space(dtype=float64, shape=(14,), low=-inf, high=inf)
#   height           Space(dtype=float64, shape=(1,), low=-inf, high=inf)
#   velocity         Space(dtype=float64, shape=(9,), low=-inf, high=inf)
#   image            Space(dtype=uint8, shape=(64, 64, 3), low=0, high=255)
# Action space
#   reset            Space(dtype=bool, shape=(), low=False, high=True)
# ...

# %%
#с добавлением цветных кругов в фон
# !python /home/rodya-rad/Desktop/mipt/dreamerv3/training_dreamer.py
# Out:
# Logdir: ~/logdir/20241008T153741-example
# ['/home/rodya-rad/Desktop/mipt/dreamerv3/idealgas0.mp4']
# Loading videos for natural: 100%|█████████| 1000/1000 [00:00<00:00, 5262.76it/s]
# Observation space
#   image            Space(dtype=uint8, shape=(3, 64, 64), low=0, high=255)
#   reward           Space(dtype=float32, shape=(), low=-inf, high=inf)
#   is_first         Space(dtype=bool, shape=(), low=False, high=True)
#   is_last          Space(dtype=bool, shape=(), low=False, high=True)
#   is_terminal      Space(dtype=bool, shape=(), low=False, high=True)
# Action space
#   action           Space(dtype=float32, shape=(6,), low=-1.0, high=1.0)
#   reset            Space(dtype=bool, shape=(), low=False, high=True)
# Encoder: {'image': (3, 64, 64)}
# Decoder: {'image': (3, 64, 64)}
# JAX devices (1): [CudaDevice(id=0)]
# Policy devices: cuda:0
# Train devices:  cuda:0
# Tracing train function
# ENC
# Изначальне
# (16, 64, 3, 64, 64)
# После решейпа в энкодере
# (1024, 3, 64, 64)
# ...

# %%
#Dreamer с бисимуляционной метрикой
# !python /home/rodya-rad/Desktop/mipt/dreamerv3/training_bisim_dreamer.py

# %% [markdown]
# # **Графики**
