# %% [markdown]
# # **Обучение**

# %%
# !git clone https://github.com/Rodyarad/dreamerv3
# Out:
# Cloning into 'dreamerv3'...
# remote: Enumerating objects: 555, done.
# remote: Counting objects: 100% (399/399), done.
# remote: Compressing objects: 100% (287/287), done.
# remote: Total 555 (delta 197), reused 216 (delta 111), pack-reused 156 (from 1)
# Receiving objects: 100% (555/555), 26.64 MiB | 26.44 MiB/s, done.
# Resolving deltas: 100% (216/216), done.

# %%
# %cd /content/dreamerv3
# !git pull
# Out:
# /content/dreamerv3
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 2), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 2.62 KiB | 894.00 KiB/s, done.
# From https://github.com/Rodyarad/dreamerv3
#    688e52b..f5d7302  main       -> origin/main
# Updating 688e52b..f5d7302
# Fast-forward
#  dmc2gym/natural_imgsource.py           |  2 --
#  training_dreamer_without_distractor.py | 72 ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  2 files changed, 72 insertions(+), 2 deletions(-)
#  create mode 100644 training_dreamer_without_distractor.py

# %%
# !pip install -r /content/dreamerv3/dreamerv3/requirements.txt

# %%
#обычный dreamer с немодифированной средой
# !python /content/dreamerv3/training_dreamer_without_distractor.py
# Out:
# 2024-10-03 14:25:07.926803: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-03 14:25:07.947456: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-03 14:25:07.953784: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-03 14:25:09.040199: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Logdir: ~/logdir/20241003T142510-example
# /usr/local/lib/python3.10/dist-packages/glfw/__init__.py:914: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# ...

# %%
#с добавлением цветных кругов в фон
# !python /content/dreamerv3/training_dreamer.py

# %%
#Dreamer с бисимуляционной метрикой
# !python /content/dreamerv3/training_bisim_dreamer.py

# %%
# %load_ext tensorboard
# %tensorboard --logdir logdir

# %% [markdown]
# # **Графики**
