# %% [markdown]
# # **Обучение**

# %%
#env with distractor, original DreamerV3
# !python training_dreamer.py
# Out:
# Logdir: ~/logdir/log_orig_dreamerv3
# ['/home/rodya-rad/Desktop/mipt/dreamerv3/idealgas0.mp4']
# Loading videos for natural: 100%|████████| 1000/1000 [00:00<00:00, 12047.51it/s]
# /home/rodya-rad/anaconda3/envs/dream/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/rodya-rad/anaconda3/envs/dream/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Observation space
#   image            Space(dtype=uint8, shape=(64, 64, 3), low=0, high=255)
# ...

# %%
#DreamerV3 with bisimulation loss
# !python training_bisim_dreamer.py
# Out:
# Logdir: ~/logdir/log_bisim_dreamerv3
# ['/home/rodya-rad/Desktop/mipt/dreamerv3/idealgas0.mp4']
# Loading videos for natural: 100%|████████| 1000/1000 [00:00<00:00, 10158.65it/s]
# /home/rodya-rad/anaconda3/envs/dream/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/rodya-rad/anaconda3/envs/dream/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Observation space
#   image            Space(dtype=uint8, shape=(64, 64, 3), low=0, high=255)
# ...

# %% [markdown]
# # **Графики**

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('/home/rodya-rad/Desktop/mipt/dreamerv3/wandb_export_2024-10-10T16_41_28.503+03_00.csv')

plot =sns.lineplot(data=df, x='Step', y='log_orig_dreamerv3 - episode/score')
plot.set(xlabel='Steps', ylabel='Score')
# Out:
# [Text(0.5, 0, 'Steps'), Text(0, 0.5, 'Score')]
